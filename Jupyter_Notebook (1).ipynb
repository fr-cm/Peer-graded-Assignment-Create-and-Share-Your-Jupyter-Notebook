# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# <h1>My jupiter Notebook on IBM Watson Studio<h1>

# %% [markdown]
# **Francesco Camassa**
# Student

# %% [markdown]
# *I am interested in data science because I am passionate about probabilistic quantification.
# The study of data can extract important information that can make a real difference.*

# %% [markdown]
# <h3>The following code will plot a Triangle<h3>

# %%
import matplotlib.pyplot as plt

A=[1, 2 , 3, 1]
B=[1, 3 , 1, 1]

plt.plot(A,B,color = 'red')
plt.title("TRIANGLE")
plt.grid()
plt.xlabel("A") 
plt.ylabel("B")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ## A & B
# * uno  &  uno
# * due  &  tre
# * tre  &  uno
# * uno  &  uno
#
#
#
#
#  **Variable** |*I* | *II* | *III* | *IV*
# --------------|----|------|-------|-----
# **A**|1|2|3|1
# **B**|1|3|1|1
#
# <del>This text has been deleted.<dek>
#
# [TRIANGLE](https://en.wikipedia.org/wiki/Triangle)
#
#
# ![](https://en.wikipedia.org/wiki/Triangle#/media/File:Triangle.Equilateral.svg)
